# %% [markdown]
# ## Les bases de Pandas

# %%
import pandas as pd

# %% [markdown]
# CSV: Comma separated value
# Dans les pays qui utilisent des versions non anglaises d'Excel, on peut avoir des fichiers avec un ; comme séparateur: adapter l'argument dep.
#
# Autre delimiteurs:
# tab
# |
# \#
#  Pour normer les colonnes, on utilise names=['col1','col2','col3']
#  pour lire que n lignes, on utilise nrows=10_000
#  Ici n=10_000

# %%
cities_df =pd.read_csv('./population.csv',
                        sep=',',
                        encoding='cp1252')

# %%
df=(pd.read_csv('./population.csv',
                        sep=',',
                        encoding='cp1252', 
                        header=None,
                        names=['col1','col2', 'col3', 'col4','col5'],
                        usecols
                        dtype={'col1':str,'col3':int},
                        nrows=10)
               )
# Out:
#   Cell In[16], line 6
#     usecols
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
cities_df1 = pd.read_csv('./population.csv', sep=',', encoding='latin-1')

# %%
cities_df1
# Out:
#             City / Urban area      Country  Population  Land area  Density
# 0              Tokyo/Yokohama        Japan    33200000       6993     4750
# 1              New York Metro          USA    17800000       8683     2050
# 2                   Sao Paulo       Brazil    17700000       1968     9000
# 3               Seoul/Incheon  South Korea    17500000       1049    16700
# 4                 Mexico City       Mexico    17400000       2072     8400
# ..                        ...          ...         ...        ...      ...
# 120                Copenhagen      Denmark     1525000        816     1850
# 121                  Brisbane    Australia     1508000       1603      950
# 122  Riverside/San Bernardino          USA     1507000       1136     1350
# 123                Cincinnati          USA     1503000       1740      850
# 124                     Accra        Ghana     1500000        453     3300
#
# [125 rows x 5 columns]

# %%
type(cities_df)
# Out:
# pandas.core.frame.DataFrame

# %%
cities_df.shape
# Out:
# (125, 5)

# %%
# Nombre de ligne de data frame
cities_df.shape[0]
# Out:
# 125

# %%
# Nombre de colonne de data frame
cities_df.shape[1]
# Out:
# 5

# %%
assert cities_df.shape[0] >= 100, "le nombre de lignes est trop pétit (au moins 100 lignes néccessaires)"

# %% [markdown]
# ## Information sur le data frame

# %%
cities_df.columns
# Out:
# Index(['City / Urban area', 'Country', 'Population', 'Land area', 'Density'], dtype='object')

# %%
cities_df.columns[-1]
# Out:
# 'Density'

# %%
cities_df.dtypes
# Out:
# City / Urban area    object
# Country              object
# Population            int64
# Land area             int64
# Density               int64
# dtype: object

# %%
cities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City / Urban area  125 non-null    object
#  1   Country            125 non-null    object
#  2   Population         125 non-null    int64
#  3   Land area          125 non-null    int64
#  4   Density            125 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 5.0+ KB

# %%
cities_df.describe()
# Out:
#          Population    Land area       Density
# count  1.250000e+02   125.000000    125.000000
# mean   5.283232e+06  1399.624000   5403.600000
# std    4.855835e+06  1340.851906   4935.181371
# min    1.500000e+06   376.000000    700.000000
# 25%    2.100000e+06   583.000000   2250.000000
# 50%    3.502000e+06   816.000000   3800.000000
# 75%    6.000000e+06  1740.000000   7700.000000
# max    3.320000e+07  8683.000000  29650.000000

# %%
cities_df.describe(include="all")
# Out:
#        City / Urban area Country    Population    Land area       Density
# count                125     125  1.250000e+02   125.000000    125.000000
# unique               125      52           NaN          NaN           NaN
# top       Tokyo/Yokohama     USA           NaN          NaN           NaN
# freq                   1      26           NaN          NaN           NaN
# mean                 NaN     NaN  5.283232e+06  1399.624000   5403.600000
# std                  NaN     NaN  4.855835e+06  1340.851906   4935.181371
# min                  NaN     NaN  1.500000e+06   376.000000    700.000000
# 25%                  NaN     NaN  2.100000e+06   583.000000   2250.000000
# 50%                  NaN     NaN  3.502000e+06   816.000000   3800.000000
# 75%                  NaN     NaN  6.000000e+06  1740.000000   7700.000000
# max                  NaN     NaN  3.320000e+07  8683.000000  29650.000000

# %% [markdown]
# ## Statistiques de base

# %%
cities_df['Population']
# Out:
# 0      33200000
# 1      17800000
# 2      17700000
# 3      17500000
# 4      17400000
#          ...
# 120     1525000
# 121     1508000
# 122     1507000
# 123     1503000
# 124     1500000
# Name: Population, Length: 125, dtype: int64

# %%
pd.read_clipboard()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pd.read_clipboard()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\clipboards.py:129, in read_clipboard(sep, dtype_backend, **kwargs)
#     123 elif len(sep) > 1 and kwargs.get("engine") == "c":
#     124     warnings.warn(
#     125         "read_clipboard with regex separator does not work properly with c engine.",
#     126         stacklevel=find_stack_level(),
#     127     )
# --> 129 return read_csv(StringIO(text), sep=sep, dtype_backend=dtype_backend, **kwargs)
#
# ...

# %% [markdown]
#  df.drop_duplicates(): pour supprimer les doublons de lignes
#  df.dropna(): pour supprimer les donner manquantes
#  df.filter(): pour filtrer les lignes
#  les fonctions peuvent travailler sur les lignes et sur les colonnes
#  df.groupby('x'): pour faire des regrouppement
#  df.fillna(): pour remplir les valeurs manquantes
#  df.stack() : pour transformer les lignes en colonnes ou des colonnes en lignes
#  df.concat([";"],axis=0) : pour concatener deux colonnes ou deux lignes

# %% [markdown]
# ### Structure du dataframe

# %%
cities_df.shape
# Out:
# (125, 5)

# %%
# Nombre de ligne
cities_df.shape[0]
# Out:
# 125

# %%
# Nombres de colonnes
cities_df.shape[1]
# Out:
# 5

# %%
# nb_rows contient le nombre de ligne
nb_rows=cities_df.shape[0]

# %%
# liste des colonnes
cities_df.columns
# Out:
# Index(['City / Urban area', 'Country', 'Population', 'Land area', 'Density'], dtype='object')

# %% [markdown]
# ### Informations sur dataframe

# %%
# Information de type
# pandas historique
# - objet (tout type de données, chaines caractères, nombres melangés, s'il y a une valeur manquante dans les données)
# il existe des types numeriques avec les données manquantes

cities_df.dtypes
# Out:
# City / Urban area    object
# Country              object
# Population            int64
# Land area             int64
# Density               int64
# dtype: object

# %% [markdown]
# ### Informations techniques

# %%
cities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City / Urban area  125 non-null    object
#  1   Country            125 non-null    object
#  2   Population         125 non-null    int64
#  3   Land area          125 non-null    int64
#  4   Density            125 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 5.0+ KB

# %%
# description statistique
cities_df.describe()
# Out:
#          Population    Land area       Density
# count  1.250000e+02   125.000000    125.000000
# mean   5.283232e+06  1399.624000   5403.600000
# std    4.855835e+06  1340.851906   4935.181371
# min    1.500000e+06   376.000000    700.000000
# 25%    2.100000e+06   583.000000   2250.000000
# 50%    3.502000e+06   816.000000   3800.000000
# 75%    6.000000e+06  1740.000000   7700.000000
# max    3.320000e+07  8683.000000  29650.000000

# %%
cities_df.describe(include='all', percentiles=[0.05,0.95])
# Out:
#        City / Urban area Country    Population    Land area       Density
# count                125     125  1.250000e+02   125.000000    125.000000
# unique               125      52           NaN          NaN           NaN
# top       Tokyo/Yokohama     USA           NaN          NaN           NaN
# freq                   1      26           NaN          NaN           NaN
# mean                 NaN     NaN  5.283232e+06  1399.624000   5403.600000
# std                  NaN     NaN  4.855835e+06  1340.851906   4935.181371
# min                  NaN     NaN  1.500000e+06   376.000000    700.000000
# 5%                   NaN     NaN  1.540400e+06   453.000000    960.000000
# 50%                  NaN     NaN  3.502000e+06   816.000000   3800.000000
# 95%                  NaN     NaN  1.467000e+07  4184.800000  15030.000000
# max                  NaN     NaN  3.320000e+07  8683.000000  29650.000000

# %%
cities_df.head(8)
# Out:
#   City / Urban area      Country  Population  Land area  Density
# 0    Tokyo/Yokohama        Japan    33200000       6993     4750
# 1    New York Metro          USA    17800000       8683     2050
# 2         Sao Paulo       Brazil    17700000       1968     9000
# 3     Seoul/Incheon  South Korea    17500000       1049    16700
# 4       Mexico City       Mexico    17400000       2072     8400
# 5  Osaka/Kobe/Kyoto        Japan    16425000       2564     6400
# 6            Manila  Philippines    14750000       1399    10550
# 7            Mumbai        India    14350000        484    29650

# %% [markdown]
# ### Lecture de fichiers Excel

# %%
pd.read_excel('./population.xlsx')
# Out:
#      Unnamed: 0                      City      Country  Population  Land area  \
# 0             0            Tokyo/Yokohama        Japan    33200000       6993
# 1             1            New York Metro          USA    17800000       8683
# 2             2                 Sao Paulo       Brazil    17700000       1968
# 3             3             Seoul/Incheon  South Korea    17500000       1049
# 4             4               Mexico City       Mexico    17400000       2072
# ..          ...                       ...          ...         ...        ...
# 120         120                Copenhagen      Denmark     1525000        816
# 121         121                  Brisbane    Australia     1508000       1603
# 122         122  Riverside/San Bernardino          USA     1507000       1136
# 123         123                Cincinnati          USA     1503000       1740
# 124         124                     Accra        Ghana     1500000        453
#
#      Density
# 0       4750
# ...

# %%
# l'installation d'un moteur des fichiers Excel peut etre nécessaire
# ! permet d'exécuter une commande sur le système, ici l'installation d'un module
# !pip install openpyxl

# %%
pd.read_excel('./population.xlsx').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  125 non-null    int64
#  1   City        125 non-null    object
#  2   Country     125 non-null    object
#  3   Population  125 non-null    int64
#  4   Land area   125 non-null    int64
#  5   Density     125 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 6.0+ KB

# %%
# on peut aussi faire
ddf=pd.read_excel('./population.xlsx')
ddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  125 non-null    int64
#  1   City        125 non-null    object
#  2   Country     125 non-null    object
#  3   Population  125 non-null    int64
#  4   Land area   125 non-null    int64
#  5   Density     125 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 6.0+ KB

# %%
# Illustration sur la suppression d'une colonne
pd.read_excel('./population.xlsx').drop(columns=['Unnamed: 0 ']).info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 2
#       1 # Illustration sur la suppression d'une colonne
# ----> 2 pd.read_excel('./population.xlsx').drop(columns=['Unnamed: 0 ']).info()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...

# %% [markdown]
# ###Lecture de données depuis une base de données SQL

# %%
import sqlite3
# Création de connexion vers la base de données
cnx=sqlite3.connect('population.sqlite')

# %%
pd.read_sql_query('SELECT*FROM population',cnx)
# Out:
#                          City      Country  Population  Land area  Density
# 0              Tokyo/Yokohama        Japan    33200000       6993     4750
# 1              New York Metro          USA    17800000       8683     2050
# 2                   Sao Paulo       Brazil    17700000       1968     9000
# 3               Seoul/Incheon  South Korea    17500000       1049    16700
# 4                 Mexico City       Mexico    17400000       2072     8400
# ..                        ...          ...         ...        ...      ...
# 120                Copenhagen      Denmark     1525000        816     1850
# 121                  Brisbane    Australia     1508000       1603      950
# 122  Riverside/San Bernardino          USA     1507000       1136     1350
# 123                Cincinnati          USA     1503000       1740      850
# 124                     Accra        Ghana     1500000        453     3300
#
# [125 rows x 5 columns]

# %%
pd.read_sql_query('SELECT*FROM population',cnx).head(5)
# Out:
#              City      Country  Population  Land area  Density
# 0  Tokyo/Yokohama        Japan    33200000       6993     4750
# 1  New York Metro          USA    17800000       8683     2050
# 2       Sao Paulo       Brazil    17700000       1968     9000
# 3   Seoul/Incheon  South Korea    17500000       1049    16700
# 4     Mexico City       Mexico    17400000       2072     8400

# %%
pd.read_sql_query('SELECT*FROM population',cnx).head()
# Out:
#              City      Country  Population  Land area  Density
# 0  Tokyo/Yokohama        Japan    33200000       6993     4750
# 1  New York Metro          USA    17800000       8683     2050
# 2       Sao Paulo       Brazil    17700000       1968     9000
# 3   Seoul/Incheon  South Korea    17500000       1049    16700
# 4     Mexico City       Mexico    17400000       2072     8400

# %%
# Utilisation de clause where
# ici recuperation que de USA
pd.read_sql_query('SELECT*FROM population WHERE Country = "USA" ',cnx)
# Out:
#                         City Country  Population  Land area  Density
# 0             New York Metro     USA    17800000       8683     2050
# 1                Los Angeles     USA    11789000       4320     2750
# 2                    Chicago     USA     8308000       5498     1500
# 3               Philadelphia     USA     5149000       4661     1100
# 4                      Miami     USA     4919000       2891     1700
# 5          Dallas/Fort Worth     USA     4146000       3644     1150
# 6                     Boston     USA     4032000       4497      900
# 7                 Washington     USA     3934000       2996     1300
# 8                    Detroit     USA     3903000       3267     1200
# 9                    Houston     USA     3823000       3355     1150
# 10                   Atlanta     USA     3500000       5083      700
# 11     San Francisco/Oakland     USA     3229000       1365     2350
# 12              Phoenix/Mesa     USA     2907000       2069     1400
# ...

# %%
pd.read_sql_query('SELECT*FROM population WHERE Country = "USA" ',cnx).shape
# Out:
# (26, 5)

# %% [markdown]
# ### Les fonctions de traitement de données
# - trouver les valeurs manquantes
# - remplacer les valeurs manquantes
# - trouver les valeurs abberantes
# - filtrer des lignes
# - calculer des nouvelles colonnes
# - agreger/ regrouper des lignes
# - croiser des tables(jointure)

# %% [markdown]
# ### Valuers manquantes

# %%
cities_df.dropna()
# Out:
#             City / Urban area      Country  Population  Land area  Density
# 0              Tokyo/Yokohama        Japan    33200000       6993     4750
# 1              New York Metro          USA    17800000       8683     2050
# 2                   Sao Paulo       Brazil    17700000       1968     9000
# 3               Seoul/Incheon  South Korea    17500000       1049    16700
# 4                 Mexico City       Mexico    17400000       2072     8400
# ..                        ...          ...         ...        ...      ...
# 120                Copenhagen      Denmark     1525000        816     1850
# 121                  Brisbane    Australia     1508000       1603      950
# 122  Riverside/San Bernardino          USA     1507000       1136     1350
# 123                Cincinnati          USA     1503000       1740      850
# 124                     Accra        Ghana     1500000        453     3300
#
# [125 rows x 5 columns]

# %%
cities_df.isna().head()
# Out:
#    City / Urban area  Country  Population  Land area  Density
# 0              False    False       False      False    False
# 1              False    False       False      False    False
# 2              False    False       False      False    False
# 3              False    False       False      False    False
# 4              False    False       False      False    False

# %%
# En phyton, True = 1, False = 0
cities_df.isna().sum()
# Out:
# City / Urban area    0
# Country              0
# Population           0
# Land area            0
# Density              0
# dtype: int64

# %% [markdown]
# ### Pour selectionner une colonne

# %%
cities_df['Country']
# Out:
# 0            Japan
# 1              USA
# 2           Brazil
# 3      South Korea
# 4           Mexico
#           ...
# 120        Denmark
# 121      Australia
# 122            USA
# 123            USA
# 124          Ghana
# Name: Country, Length: 125, dtype: object

# %%
cities_df['Country'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 120    False
# 121    False
# 122    False
# 123    False
# 124    False
# Name: Country, Length: 125, dtype: bool

# %%
cities_df['Country'].isna().sum()
# Out:
# 0

# %%
# Permet de filtrer (et voir) les lignes pour lesquelles on a des valeurs manquantes
#  Remarque : df[ ..........] permet de filtrer 
cities_df[cities_df['Country'].isna()]
# Out:
# Empty DataFrame
# Columns: [City / Urban area, Country, Population, Land area, Density]
# Index: []

# %%
cities_df['Population']>=15_000_000
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 120    False
# 121    False
# 122    False
# 123    False
# 124    False
# Name: Population, Length: 125, dtype: bool

# %%
cities_df[cities_df['Population']>=15_000_000]
# Out:
#   City / Urban area      Country  Population  Land area  Density
# 0    Tokyo/Yokohama        Japan    33200000       6993     4750
# 1    New York Metro          USA    17800000       8683     2050
# 2         Sao Paulo       Brazil    17700000       1968     9000
# 3     Seoul/Incheon  South Korea    17500000       1049    16700
# 4       Mexico City       Mexico    17400000       2072     8400
# 5  Osaka/Kobe/Kyoto        Japan    16425000       2564     6400

# %%
# Mode avancé!!!
# On utilise le resultat de l'expression booléenne qui est une série (comme une autre, une colonne, etc.) pour faire un calcule 
#Les parenthèses permettent de bien isoler l'objet / Le resultat sur l'application de la fonction .sum()
(cities_df['Population']>=15_000_000).sum()
# Out:
# 6

# %%
cities_15M_df = cities_df [cities_df['Population']>=15_000_000]

# %%
cities_15M_df
# Out:
#   City / Urban area      Country  Population  Land area  Density
# 0    Tokyo/Yokohama        Japan    33200000       6993     4750
# 1    New York Metro          USA    17800000       8683     2050
# 2         Sao Paulo       Brazil    17700000       1968     9000
# 3     Seoul/Incheon  South Korea    17500000       1049    16700
# 4       Mexico City       Mexico    17400000       2072     8400
# 5  Osaka/Kobe/Kyoto        Japan    16425000       2564     6400

# %% [markdown]
# ### Quelques opp&rations d'énumeration

# %%
## statistiques sur les colonnes

# %%
print(cities_df['Population'].mean())
print(cities_df['Population'].mode())
print(cities_df['Population'].())
# Out:
# 5283232.0
# 0    4000000
# Name: Population, dtype: int64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27284\568496960.py in ?()
#       1 print(cities_df['Population'].mean())
#       2 print(cities_df['Population'].mode())
# ----> 3 print(cities_df['Population'].sd())
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'sd'

# %%
cities_df['Country'].unique()
# Out:
# array(['Japan', 'USA', 'Brazil', 'South Korea', 'Mexico', 'Philippines',
#        'India', 'Indonesia', 'Nigeria', 'Egypt', 'Argentina', 'Russia',
#        'China', 'Pakistan', 'France', 'Turkey', 'UK', 'Germany', 'Iran',
#        'Colombia', 'Peru', 'Thailand', 'South Africa', 'Taiwan', 'Iraq',
#        'Chile', 'Congo', 'Vietnam', 'Spain', 'Malaysia', 'Canada',
#        'Italy', 'Sudan', 'Saudi Arabia', 'Singapore', 'Greece',
#        'Australia', 'Israel', 'Portugal', 'Puerto Rico', 'Poland',
#        'Uzbekistan', 'Azerbaijan', 'UAE', 'Lebanon', 'Hungary',
#        'Zimbabwe', 'Kuwait', 'Belgium', 'Austria', 'Denmark', 'Ghana'],
#       dtype=object)

# %%
cities_df['Country'].nunique()
# Out:
# 52

# %%
cities_df['Country'].value_counts()[:5]
# Out:
# Country
# USA        26
# Brazil      9
# Germany     6
# India       6
# China       6
# Name: count, dtype: int64

# %%
cities_df['Country'].value_counts()[0]
# Out:
# C:\Users\sodji\AppData\Local\Temp\ipykernel_27284\3630154804.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cities_df['Country'].value_counts()[0]
# 26

# %%
cities_df['Country'].value_counts().index[0]
# Out:
# 'USA'

# %%
## nom du deuxieme pays plus fréquents
cities_df['Country'].value_counts().index[1]
# Out:
# 'Brazil'

# %%
cities_df['Country'].value_counts()[-5:]
# Out:
# Country
# Thailand    1
# Iraq        1
# Chile       1
# Vietnam     1
# Ghana       1
# Name: count, dtype: int64

# %% [markdown]
# ### Filtrer les tableaaux

# %%
cities_df.query('Country=="USA" and Population >= 5000000')
# Out:
#    City / Urban area Country  Population  Land area  Density
# 1     New York Metro     USA    17800000       8683     2050
# 13       Los Angeles     USA    11789000       4320     2750
# 23           Chicago     USA     8308000       5498     1500
# 39      Philadelphia     USA     5149000       4661     1100

# %%
## Prenons l'habitude d' écrire les constantes en Majuscule

SEUIL_POPULATION=5_000_000

cities_df.query(f'Country=="USA" and Population >= {SEUIL_POPULATION}')
# Out:
#    City / Urban area Country  Population  Land area  Density
# 1     New York Metro     USA    17800000       8683     2050
# 13       Los Angeles     USA    11789000       4320     2750
# 23           Chicago     USA     8308000       5498     1500
# 39      Philadelphia     USA     5149000       4661     1100

# %%
PAYS_ANALYSE = 'France'
SEUIL_POPULATION = 5_000_000


cities_df.query(f'Country=="{PAYS_ANALYSE}" and Population >= {SEUIL_POPULATION}')
# Out:
#    City / Urban area Country  Population  Land area  Density
# 19             Paris  France     9645000       2723     3550

# %% [markdown]
# Créactin de nouvelles colonnes

# %%
9645000/2723
# Out:
# 3542.049210429673

# %%
## l'utilisation de l'affectation naturelle
cities_df['TrueDensity'] = cities_df['Population'] / cities_df[ 'Land area']

# %%
cities_df.head()
# Out:
#   City / Urban area      Country  Population  Land area  Density   TrueDensity
# 0    Tokyo/Yokohama        Japan    33200000       6993     4750   4747.604748
# 1    New York Metro          USA    17800000       8683     2050   2049.982725
# 2         Sao Paulo       Brazil    17700000       1968     9000   8993.902439
# 3     Seoul/Incheon  South Korea    17500000       1049    16700  16682.554814
# 4       Mexico City       Mexico    17400000       2072     8400   8397.683398

# %% [markdown]
# ## Traitement des chaines de caractères

# %%
## L' accesseur str permet de travailler sur les chaines de caractères

# %%
cities_df['Country'].str[0]
# Out:
# 0      J
# 1      U
# 2      B
# 3      S
# 4      M
#       ..
# 120    D
# 121    A
# 122    U
# 123    U
# 124    G
# Name: Country, Length: 125, dtype: object

# %%
## deux premières caractères de la chaine
cities_df['Country'].str[:2]
# Out:
# 0      Ja
# 1      US
# 2      Br
# 3      So
# 4      Me
#        ..
# 120    De
# 121    Au
# 122    US
# 123    US
# 124    Gh
# Name: Country, Length: 125, dtype: object

# %%
'DES MAJUSCULE'.lower()
# Out:
# 'des majuscule'

# %%
cities_df['Country'].str.lower().head()
# Out:
# 0          japan
# 1            usa
# 2         brazil
# 3    south korea
# 4         mexico
# Name: Country, dtype: object

# %%
 ##Sans accesseur str, la fonction ne marche pas car il va falloir interpreter les elements de notre data comme 
## caractères avant d'y appliquer la fonction liée aux chaines de caractères
cities_df['Country'].lower().head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27284\2252426003.py in ?()
#       1 ##Sans accesseur str, la fonction ne marche pas car il va falloir interpreter les elements de notre data comme
#       2 ## caractères avant d'y appliquer la fonction liée aux chaines de caractères
# ----> 3 cities_df['Country'].lower().head()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'lower'

# %%
# Series 
cities_df[cities_df['Country'].str.lower().str.contains ('s')].head(3)
# Out:
#   City / Urban area      Country  Population  Land area  Density   TrueDensity
# 1    New York Metro          USA    17800000       8683     2050   2049.982725
# 3     Seoul/Incheon  South Korea    17500000       1049    16700  16682.554814
# 6            Manila  Philippines    14750000       1399    10550  10543.245175

# %%
cities_df[cities_df['Country'].str.lower().str.contains ('a')]['Country']. unique()
# Out:
# array(['Japan', 'USA', 'Brazil', 'South Korea', 'India', 'Indonesia',
#        'Nigeria', 'Argentina', 'Russia', 'China', 'Pakistan', 'France',
#        'Germany', 'Iran', 'Colombia', 'Thailand', 'South Africa',
#        'Taiwan', 'Iraq', 'Vietnam', 'Spain', 'Malaysia', 'Canada',
#        'Italy', 'Sudan', 'Saudi Arabia', 'Singapore', 'Australia',
#        'Israel', 'Portugal', 'Poland', 'Uzbekistan', 'Azerbaijan', 'UAE',
#        'Lebanon', 'Hungary', 'Zimbabwe', 'Kuwait', 'Austria', 'Denmark',
#        'Ghana'], dtype=object)

# %%
cities_df.query('Country.str.lower().str.contains ("a")').head(3)
# Out:
#   City / Urban area Country  Population  Land area  Density  TrueDensity
# 0    Tokyo/Yokohama   Japan    33200000       6993     4750  4747.604748
# 1    New York Metro     USA    17800000       8683     2050  2049.982725
# 2         Sao Paulo  Brazil    17700000       1968     9000  8993.902439

# %%
transcoder = { 'USA' : 'United States of America', 'UK' : 'United Kingdom'}

# %%
cities_df.replace({'Country': transcoder})['Country'].unique()
# Out:
# array(['Japan', 'United States of America', 'Brazil', 'South Korea',
#        'Mexico', 'Philippines', 'India', 'Indonesia', 'Nigeria', 'Egypt',
#        'Argentina', 'Russia', 'China', 'Pakistan', 'France', 'Turkey',
#        'United Kingdom', 'Germany', 'Iran', 'Colombia', 'Peru',
#        'Thailand', 'South Africa', 'Taiwan', 'Iraq', 'Chile', 'Congo',
#        'Vietnam', 'Spain', 'Malaysia', 'Canada', 'Italy', 'Sudan',
#        'Saudi Arabia', 'Singapore', 'Greece', 'Australia', 'Israel',
#        'Portugal', 'Puerto Rico', 'Poland', 'Uzbekistan', 'Azerbaijan',
#        'UAE', 'Lebanon', 'Hungary', 'Zimbabwe', 'Kuwait', 'Belgium',
#        'Austria', 'Denmark', 'Ghana'], dtype=object)

# %% [markdown]
# ## Regroupement de lignes/ agrégats/ group by

# %%
cities_df.groupby(['Country'])

# %%
cities_df.groupby(['Country'])['Population'].mean().head(3)
# Out:
# Country
# Argentina    11200000.0
# Australia     2724000.0
# Austria       1550000.0
# Name: Population, dtype: float64

# %% [markdown]
# L'astuce de la parenthèse (parentheis trich)

# %%
( cities_df
 .groupby(['Country'])
  .agg({'Population': ['mean', 'max', 'sum'], 'Land area':['mean', 'max', 'sum']})
 .head(3)
)
# Out:
#            Population                     Land area
#                  mean       max       sum      mean   max   sum
# Country
# Argentina  11200000.0  11200000  11200000    2266.0  2266  2266
# Australia   2724000.0   3502000   8172000    1790.0  2080  5370
# Austria     1550000.0   1550000   1550000     453.0   453   453

# %% [markdown]
# ### Visualisation
